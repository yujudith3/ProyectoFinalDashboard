# %% [markdown]
# <a href="https://colab.research.google.com/github/yujudith3/ProyectoFinalDashboard/blob/main/Tarea_5___Jalisco_PEA_Judith_Navarro_Marco_Hernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TAREA 5 _ PROYECTO FINAL TÓPICOS DE INDUSTRIA
#
# **Nombre:** Judith Guadalupe Navarro Flores
#
# **e-mail:** judith.navarro4332@alumnos.udg.mx
#
# **Nombre:** Marco Antonio Hernández Preciado
# **e-mail:** marco.hpreciado@alumnos.udg.mx

# %%
import math
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
import plotly.graph_objects as go
import panel as pn
import panel.widgets as pnw

import plotly.express as px
pn.extension('plotly')

from google.colab import drive
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='70fdee25-19e9-4d82-81ed-86df1379b132'>
#   <div id="c1bbdd60-cdce-4a25-a6bb-30c21ff9d9d2" data-root-id="70fdee25-19e9-4d82-81ed-86df1379b132" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='68183d34-f4c1-45fb-84f6-56ff9b52f073'>
#   <div id="c3b4f3cc-fe08-40e5-83bd-0089b5599f0b" data-root-id="68183d34-f4c1-45fb-84f6-56ff9b52f073" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
jalisco_pea = pd.read_csv('/content/drive/MyDrive/Proyecto Dashboard/jalisco_pea.csv')

# %%
print(jalisco_pea.head())
# Out:
#    ENTIDAD  NOM_ENT  MUN NOM_MUN  LOC NOM_LOC AGEB  MZA  POBTOT  PEA
# 0       14  Jalisco    1  Acatic    1  Acatic  194   18      66   33
# 1       14  Jalisco    1  Acatic    1  Acatic  194   19      61   32
# 2       14  Jalisco    1  Acatic    1  Acatic  194    2      55   24
# 3       14  Jalisco    1  Acatic    1  Acatic  194   20      72   31
# 4       14  Jalisco    1  Acatic    1  Acatic  194   21      61   33

# %%
## funcion para filtrar datos de columna Poblacion Total POBTOT##

def filtrodatos_pob(jalisco_pea, valor_minimo, valor_maximo):
  datosfiltrados_pob = jalisco_pea[(jalisco_pea['POBTOT']>=valor_minimo)&(jalisco_pea['POBTOT']<=valor_maximo)]
  return datosfiltrados_pob

# %%
# crear widgets

#Sliders para poner limites en la columna Poblacion Total (POBTOT)
min_slider_pob = pnw.IntInput(name='valor Minimo POBTOT', start=0, end=1385629, step=10, value=0)
max_slider_pob = pnw.IntInput(name='valor Maximo POBTOT', start=0, end=1385629, step=10, value=100)

#Sliders para poner limites en la columna Poblacion Economicamente Activa (PEA)

min_slider_pea = pnw.IntInput(name='valor Minimo PEA', start=0, end=747410, step=10, value=0)
max_slider_pea = pnw.IntInput(name='valor Maximo PEA', start=0, end=747410, step=10, value=100)

# %%
##funcion para filtrar datos de columna Poblacion Economicamente Activa PEA ##

def filtrodatos_pea(jalisco_pea, valor_minimo, valor_maximo):
  datosfiltrados_pea = jalisco_pea[(jalisco_pea['PEA']>=valor_minimo)&(jalisco_pea['PEA']<=valor_maximo)]
  return datosfiltrados_pea

# %%
## definir funcion de actualizacion ##
@pn.depends(min_slider_pob, max_slider_pob)
def actualizardatos_pob(min_slider_pob, max_slider_pob):
  valor_minimo=min_slider_pob.value
  valor_maximo=max_slider_pob.value
  datosfiltrados_pob=filtrodatos_pob(jalisco_pea, valor_minimo, valor_maximo)
  datosfiltrados_pob.to_csv('datos_filtrados.csv', index=False)
  print("los datos filtrados han sido exportados a 'datos_filtrados.csv'")

# %%
## definir funcion de actualizacion ##
@pn.depends(min_slider_pea, max_slider_pea)
def actualizardatos_pea(min_slider_pea, max_slider_pea):
  valor_minimo=min_slider_pea.value
  valor_maximo=max_slider_pea.value
  datosfiltrados_pea=filtrodatos_pea(jalisco_pea, valor_minimo, valor_maximo)
  datosfiltrados_pea.to_csv('datos_filtrados.csv', index=False)
  print("los datos filtrados han sido exportados a 'datos_filtrados.csv'")

# %%
actualizardatos_pob(min_slider_pob, max_slider_pob)
# Out:
# los datos filtrados han sido exportados a 'datos_filtrados.csv'

# %%
actualizardatos_pea(min_slider_pea, max_slider_pea)
# Out:
# los datos filtrados han sido exportados a 'datos_filtrados.csv'

# %%
datos_filtrados = pd.read_csv('datos_filtrados.csv')

datos_filtrados.head()
# Out:
#    ENTIDAD  NOM_ENT  MUN NOM_MUN  LOC NOM_LOC AGEB  MZA  POBTOT  PEA
# 0       14  Jalisco    1  Acatic    1  Acatic  194   18      66   33
# 1       14  Jalisco    1  Acatic    1  Acatic  194   19      61   32
# 2       14  Jalisco    1  Acatic    1  Acatic  194    2      55   24
# 3       14  Jalisco    1  Acatic    1  Acatic  194   20      72   31
# 4       14  Jalisco    1  Acatic    1  Acatic  194   21      61   33

# %%
min_slider_pob.param.watch(actualizardatos_pob, 'value')
max_slider_pob.param.watch(actualizardatos_pob, 'value')
min_slider_pea.param.watch(actualizardatos_pea, 'value')
max_slider_pea.param.watch(actualizardatos_pea, 'value')
# Out:
# Watcher(inst=IntInput(end=747410, name='valor Maximo PEA', start=0, step=10, value=100), cls=<class 'panel.widgets.input.IntInput'>, fn=<function actualizardatos_pea at 0x7aaf5be24820>, mode='args', onlychanged=True, parameter_names=('value',), what='value', queued=False, precedence=0)

# %%
dashboard = pn.Row(
    pn.Column(
        min_slider_pob,
        max_slider_pob,
        min_slider_pea,
        max_slider_pea
    ),
    datos_filtrados.head(10)
)

dashboard.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <pre>Traceback (most recent call last):
#   File &quot;/usr/local/lib/python3.10/dist-packages/pyviz_comms/__init__.py&quot;, line 340, in _handle_msg
#     self._on_msg(msg)
#   File &quot;/usr/local/lib/python3.10/dist-packages/panel/viewable.py&quot;, line 478, in _on_msg
#     doc.unhold()
#   File &quot;/usr/local/lib/python3.10/dist-packages/bokeh/document/document.py&quot;, line 776, in unhold
#     self.callbacks.unhold()
# ...

# %%
# Replace 'latin-1' with the actual encoding of your file
coordenadas = pd.read_csv('/content/drive/MyDrive/Proyecto Dashboard/coordenadas.csv', encoding='latin-1')

#coordenadas = pd.read_csv('/content/drive/MyDrive/Proyecto Dashboard/coordenadas.csv')

# Seleccionar las variables
variables = ['Ciudad', 'longitud', 'latitud']

coordenadas = coordenadas[variables]

# Filtrar el DataFrame a Jalisco
#coordenadas = coordenadas[coordenadas['Ciudad'] == 'Guadalajara']

# Crear el mapa
mapa = px.scatter_mapbox(coordenadas, lat='latitud', lon='longitud',
                        color='Ciudad', zoom=6)

# Mostrar el mapa
pn.Row(mapa).servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row
#     [0] Plotly(Figure)

# %% [markdown]
# ## Gráfico de Dispersión entre POBTOT y PEA

# %%
grafico_dispersion = px.scatter(datos_filtrados, x='POBTOT', y='PEA',
                                 trendline='ols')

pn.Row(grafico_dispersion).servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row
#     [0] Plotly(Figure)

# %% [markdown]
# ## Histograma de POBTOT

# %%
histograma = go.Histogram(x=datos_filtrados['POBTOT'])

layout = go.Layout(title='Distribución de la población total')

fig = go.Figure(data=histograma, layout=layout)

pn.Row(fig).servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row
#     [0] Plotly(Figure)
