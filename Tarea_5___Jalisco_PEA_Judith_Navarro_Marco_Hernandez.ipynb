# %% [markdown]
# <a href="https://colab.research.google.com/github/yujudith3/ProyectoFinalDashboard/blob/main/Tarea_5___Jalisco_PEA_Judith_Navarro_Marco_Hernandez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TAREA 5 _ PROYECTO FINAL TÓPICOS DE INDUSTRIA
#
# **Nombre:** Judith Guadalupe Navarro Flores
#
# **e-mail:** judith.navarro4332@alumnos.udg.mx
#
# **Nombre:** Marco Antonio Hernández Preciado
# **e-mail:** marco.hpreciado@alumnos.udg.mx

# %%
import math
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
import plotly.graph_objects as go
import panel as pn
import panel.widgets as pnw

import plotly.express as px
pn.extension('plotly')

from google.colab import drive
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1bde94db-0b81-4b6a-a306-7eea2ce5496c'>
#   <div id="cd74bdd1-2880-43c9-813d-d024a46dde9f" data-root-id="1bde94db-0b81-4b6a-a306-7eea2ce5496c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b6417f12-c034-4976-8e44-6e6d7ddd4330":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1bde94db-0b81-4b6a-a306-7eea2ce5496c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"9db7a233-b072-4415-8af3-880a895e186e","attributes":{"plot_id":"1bde94db-0b81-4b6a-a306-7eea2ce5496c","comm_id":"5dc81cb1c0594cd6b6d89e206d06fcb7","client_comm_id":"56da4e2622d343ed86191ad4fea723dd"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"b6417f12-c034-4976-8e44-6e6d7ddd4330","roots":{"1bde94db-0b81-4b6a-a306-7eea2ce5496c":"cd74bdd1-2880-43c9-813d-d024a46dde9f"},"root_ids":["1bde94db-0b81-4b6a-a306-7eea2ce5496c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Plotly'] !== undefined) && ( root['Plotly'] !== undefined) && ( root['Plotly'] !== undefined) && ( root['Plotly'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='568c7156-eb4e-473c-9868-4737ea9e9362'>
#   <div id="a2973c12-1645-4e4c-ab11-c82c9edd18b2" data-root-id="568c7156-eb4e-473c-9868-4737ea9e9362" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"327c654d-bbb6-4d2c-a77c-fcdf1834ef0e":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"568c7156-eb4e-473c-9868-4737ea9e9362"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"18f331bf-978b-4977-b2a2-ff943558390f","attributes":{"plot_id":"568c7156-eb4e-473c-9868-4737ea9e9362","comm_id":"8ef26c6805fb4ca89dc41af431fb484e","client_comm_id":"74270fa877ae479b800e9042b4a047bb"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"327c654d-bbb6-4d2c-a77c-fcdf1834ef0e","roots":{"568c7156-eb4e-473c-9868-4737ea9e9362":"a2973c12-1645-4e4c-ab11-c82c9edd18b2"},"root_ids":["568c7156-eb4e-473c-9868-4737ea9e9362"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Plotly'] !== undefined) && ( root['Plotly'] !== undefined) && ( root['Plotly'] !== undefined) && ( root['Plotly'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
jalisco_pea = pd.read_csv('/content/drive/MyDrive/Proyecto Dashboard/jalisco_pea.csv')

# %%
print(jalisco_pea.head())
# Out:
#    ENTIDAD  NOM_ENT  MUN NOM_MUN  LOC NOM_LOC AGEB  MZA  POBTOT  PEA
# 0       14  Jalisco    1  Acatic    1  Acatic  194   18      66   33
# 1       14  Jalisco    1  Acatic    1  Acatic  194   19      61   32
# 2       14  Jalisco    1  Acatic    1  Acatic  194    2      55   24
# 3       14  Jalisco    1  Acatic    1  Acatic  194   20      72   31
# 4       14  Jalisco    1  Acatic    1  Acatic  194   21      61   33

# %%
# crear widgets

#Sliders para poner limites en la columna Poblacion Total (POBTOT)
min_slider_pob = pnw.IntInput(name='valor Minimo POBTOT', start=0, end=1380000, step=10, value=0)
max_slider_pob = pnw.IntInput(name='valor Maximo POBTOT', start=0, end=1380000, step=10, value=1380000)

#Sliders para poner limites en la columna Poblacion Economicamente Activa (PEA)

min_slider_pea = pnw.IntInput(name='valor Minimo PEA', start=0, end=70000, step=10, value=0)
max_slider_pea = pnw.IntInput(name='valor Maximo PEA', start=0, end=70000, step=10, value=70000)

# %%
##funcion para filtrar datos de columna Poblacion Economicamente Activa PEA ##

def filtrodatos_pob(jalisco_pea, valor_minimo, valor_maximo):
  datosfiltrados_pob = jalisco_pea[(jalisco_pea['POBTOT']>=valor_minimo)&(jalisco_pea['POBTOT']<=valor_maximo)]
  return datosfiltrados_pob

# %%
##funcion para filtrar datos de columna Poblacion Economicamente Activa PEA ##

def filtrodatos_pea(jalisco_pea, valor_minimo, valor_maximo):
  datosfiltrados_pea = jalisco_pea[(jalisco_pea['PEA']>=valor_minimo)&(jalisco_pea['PEA']<=valor_maximo)]
  return datosfiltrados_pea

# %%
## funcion para filtrar datos por Estado##

def filtrodatos_estado(jalisco_pea, estado):
  datosfiltrados_estado = jalisco_pea[(jalisco_pea['NOM_MUN'] == estado)]
  return datosfiltrados_estado

# %%
estado = pnw.Select(name='Municipios ZMG', value='Guadalajara', options=['Zapopan', 'Tlaquepaque', 'Tlajomulco', 'Guadalajara'])

# %%
## definir funcion de actualizacion ##
@pn.depends(min_slider_pob, max_slider_pob)
def actualizardatos_pob(min_slider_pob, max_slider_pob):
  valor_minimo=min_slider_pob.value
  valor_maximo=max_slider_pob.value
  datosfiltrados_pob=filtrodatos_pob(jalisco_pea, valor_minimo, valor_maximo)
  datosfiltrados_pob.to_csv('datos_filtrados.csv', index=False)
  print("los datos filtrados han sido exportados a 'datos_filtrados.csv'")

min_slider_pob.param.watch(actualizardatos_pob, 'value')
max_slider_pob.param.watch(actualizardatos_pob, 'value')
# Out:
# Watcher(inst=IntInput(end=1380000, name='valor Maximo POBTOT', start=0, step=10, value=1380000), cls=<class 'panel.widgets.input.IntInput'>, fn=<function actualizardatos_pob at 0x7aaf5b1e9360>, mode='args', onlychanged=True, parameter_names=('value',), what='value', queued=False, precedence=0)

# %%
## definir funcion de actualizacion ##
@pn.depends(min_slider_pea, max_slider_pea)
def actualizardatos_pea(min_slider_pea, max_slider_pea):
  valor_minimo=min_slider_pea.value
  valor_maximo=max_slider_pea.value
  datosfiltrados_pea=filtrodatos_pea(jalisco_pea, valor_minimo, valor_maximo)
  datosfiltrados_pea.to_csv('datos_filtrados.csv', index=False)
  print("los datos filtrados han sido exportados a 'datos_filtrados.csv'")

min_slider_pea.param.watch(actualizardatos_pea, 'value')
max_slider_pea.param.watch(actualizardatos_pea, 'value')
# Out:
# Watcher(inst=IntInput(end=70000, name='valor Maximo PEA', start=0, step=10, value=70000), cls=<class 'panel.widgets.input.IntInput'>, fn=<function actualizardatos_pea at 0x7aaf5b1ea950>, mode='args', onlychanged=True, parameter_names=('value',), what='value', queued=False, precedence=0)

# %%
#Actualizacion de Municipios de la ZMG

@pn.depends(estado)
def actualizar_municipio(estado):
  status = estado.value

  datosfiltrados_estado = filtrodatos_pob(jalisco_pea, estado)
  datosfiltrados_estado.to_csv('datos_filtrados.csv', index=False)

# %%
estado.param.watch(actualizar_municipio, 'value')
# Out:
# Watcher(inst=Select(name='Municipios ZMG', options=['Zapopan', 'Tlaquepaque',...], value='Guadalajara'), cls=<class 'panel.widgets.select.Select'>, fn=<function actualizar_municipio at 0x7aaf5b1e9990>, mode='args', onlychanged=True, parameter_names=('value',), what='value', queued=False, precedence=0)

# %%
#datos_filtrados = pd.read_csv('datos_filtrados.csv')

#datos_filtrados.head()

# %%
#Actualizar Tabla
actualizardatos_pob(min_slider_pob, max_slider_pob)
actualizardatos_pea(min_slider_pea, max_slider_pea)
datos_filtrados = pd.read_csv('datos_filtrados.csv')

datos_filtrados.head(10)
# Out:
# los datos filtrados han sido exportados a 'datos_filtrados.csv'
# los datos filtrados han sido exportados a 'datos_filtrados.csv'
#    ENTIDAD  NOM_ENT  MUN NOM_MUN  LOC NOM_LOC AGEB  MZA  POBTOT  PEA
# 0       14  Jalisco    1  Acatic    1  Acatic  194   18      66   33
# 1       14  Jalisco    1  Acatic    1  Acatic  194   19      61   32
# 2       14  Jalisco    1  Acatic    1  Acatic  194    2      55   24
# 3       14  Jalisco    1  Acatic    1  Acatic  194   20      72   31
# 4       14  Jalisco    1  Acatic    1  Acatic  194   21      61   33
# 5       14  Jalisco    1  Acatic    1  Acatic  194   22      34   14
# 6       14  Jalisco    1  Acatic    1  Acatic  194   23     105   53
# 7       14  Jalisco    1  Acatic    1  Acatic  194   24      39   16
# 8       14  Jalisco    1  Acatic    1  Acatic  194   25      68   35
# 9       14  Jalisco    1  Acatic    1  Acatic  194   26      75   32

# %%
dashboard = pn.Row(
    pn.Column(
        estado,
        min_slider_pob,
        max_slider_pob,
        min_slider_pea,
        max_slider_pea
    ),
  datos_filtrados.head(10)
)

dashboard.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row
#     [0] Column
#         [0] Select(name='Municipios ZMG', options=['Zapopan', 'Tlaquepaque',...], value='Tlaquepaque')
#         [1] IntInput(end=1380000, name='valor Minimo POBTOT', start=0, step=10)
#         [2] IntInput(end=1380000, name='valor Maximo POBTOT', start=0, step=10, value=1380000)
#         [3] IntInput(end=70000, name='valor Minimo PEA', start=0, step=10)
#         [4] IntInput(end=70000, name='valor Maximo PEA', start=0, step=10, value=70000)
#     [1] DataFrame(DataFrame)

# %% [markdown]
# ## Gráfico de Dispersión entre POBTOT y PEA

# %%
grafico_dispersion = px.scatter(datos_filtrados, x='POBTOT', y='PEA',
                                 trendline='ols')

pn.Row(grafico_dispersion).servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row
#     [0] Plotly(Figure)

# %% [markdown]
# ## Histograma de POBTOT

# %%
histograma = go.Histogram(x=datos_filtrados['POBTOT'])

layout = go.Layout(title='Distribución de la población total')

fig = go.Figure(data=histograma, layout=layout)

pn.Row(fig).servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Row
#     [0] Plotly(Figure)
